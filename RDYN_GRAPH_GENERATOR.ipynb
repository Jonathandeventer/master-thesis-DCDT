# %% [markdown]
# # Artificial graph generator Rdyn
#
#
# Generates instances of the Rdyn benchmark with multiple graphs and ground truth communities.

# %% [markdown]
# 0. Requirements

# %%
# !pip install rdyn

# %% [markdown]
# 1. Imports

# %%
from rdyn import RDyn
import os

# %% [markdown]
# 2. datapaths

# %%
datapath = 'gdrive/My Drive/data'
folder = '/rdyn_data'

# %%
# parameters 
    
    
# size describes the amount of nodes     

size = [5000, 10000, 50000, 100000, 500000, 1000000] #, 1000,5000, 10000, 50000]

# iterations describes the amount of iterations
iterations = [100,500, 1000] #, 1000,5000, 10000, 50000]

simplified = [True, False]

# %%
os.chdir(datapath+folder)

# %%
print(os.getcwd())

# %% [markdown]
# 3. benchmark generator

# %%
# worthless because keeps overriding files with the same characteristics.

rdb = RDyn(size=100000, iterations=1000)
rdb.execute(simplified=True)
# Out:
#   0%|                                                                      | 0/1000 [00:00<?, ?it/s]

# %%
from rdyn import RDyn
rdb = RDyn()
rdb.execute(simplified=True)

# %%
# to remove content in the folder results
# !rm -rf results
