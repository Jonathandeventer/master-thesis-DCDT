# %% [markdown]
# # Parser for Demon to prepare .txt files to be fed to Demon

# %% [markdown]
# **0. imports**

# %%
import json
import ast

# %% [markdown]
# **1. setup**

# %% [markdown]
# **1.1 mounting gdrive**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# **1.2 config filepaths**

# %%
filepath = 'gdrive/My Drive/data'
folder = '/amazon'
fn_all_comm = '/com-amazon.all.dedup.cmty.txt'
fn_top5000 = '/com-dblp.top5000.cmty.txt'
fn_graph = '/com-dblp.ungraph.txt'

fn_demon = '/comm_amazon_025_3.txt'
# print (filepath + fn_all_comm)

# %%
import os
cwd = os.getcwd()
print(cwd)
# Out:
# /content

# %% [markdown]
# **2. parsers**

# %% [markdown]
# **2.2 Convert demon output to list**

# %%
/dblp_comm_025_3.txt

# %% [markdown]
# **2.2 Convert list to tuple file (NF1) for gt comms**

# %%
file = filepath + folder + fn_all_comm


commands = {}
lst = []
with open(file) as fh:
    for line in fh:
        temp = []
        nodes = line.strip().split("\t")
        for node in nodes:
            temp.append(int(node))
        lst.append(temp)
        #command, description = line.strip().split('\t', 1)
        #commands[command] = ast.literal_eval(description.strip())
with open(filepath + '/amazon_comm_all_gt.txt', "w+") as fh:
    for v in lst:
        # print (v)
        fh.write(str(tuple(v))+"\n")

# %% [markdown]
# content/gdrive/My Drive/data/amazon/comm_amazon_025_3.txt

# %% [markdown]
# **2.2 Convert list to tuple file (NF1) for comms produced by algorithm**

# %%
file = filepath + folder + fn_demon

commands = {}
lst = []
with open(file) as fh:
    for line in fh:
        command, description = line.strip().split('\t', 1)
        #print(command, description)
        commands[command] = ast.literal_eval(description.strip())
        #print ( ast.literal_eval(description.strip()))
with open(filepath + '/amazon_comm_025_3.txt', "w+") as fh:
    for k,v in commands.items():
        #print (k, v)
        #print(str(tuple(v))+"\n")
        fh.write(str(tuple(v))+"\n")
