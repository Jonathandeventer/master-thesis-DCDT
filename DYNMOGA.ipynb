# %%
import os
datapath = 'gdrive/My Drive/data/'
data_folder = 'rdyn_data_6/results/'
output_folder = datapath+'dynmoga/'
algorithm_name = 'dynmoga'
#!pip install nf1
os.chdir("/content")
